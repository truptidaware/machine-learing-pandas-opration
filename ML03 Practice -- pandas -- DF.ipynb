# %% [markdown]
# # Read CSV

# %%
import pandas as pd

# %%
df = pd.read_csv('G:\\ML Practice\\emp.csv')

# %%
df
# Out:
#     id    name address
# 0  101  mahesh  mumbai
# 1  102  ganesh    pune
# 2  103  govind    pune

# %% [markdown]
# # Read EXCEL

# %%
df1 = pd.read_excel('G:\\ML Practice\\practice.xlsx')

# %%
df1
# Out:
#    id     name dept     add
# 0    1  Mahesh   AI    pune
# 1    2  Ganesh   SE  mumbai
# 2    3  Govind   SE    Pune

# %%
df2 = pd.read_excel('G:\\ML Practice\\practice.xlsx',sheet_name='work')

# %%
df2
# Out:
#     name  designation  location
# 0   Swati           DE     Pune
# 1  Trupti           SE     Pune

# %% [markdown]
# # Creating DF By Dictionary

# %%
emp_list= {
    'id' : [101,102,103,104], 
    'name': ['mahesh','ganesh','govind','sham'],
    'city' : ['pune','mumbai','pune','chennai']
    
}

# %%
df3 = pd.DataFrame(emp_list)

# %%
df3
# Out:
#     id    name     city
# 0  101  mahesh     pune
# 1  102  ganesh   mumbai
# 2  103  govind     pune
# 3  104    sham  chennai

# %% [markdown]
# # Creating DF By Dictionary of Tuple List

# %%
my_list = {
    (101,'SE','Arun'),
    (150,'AI', 'Mahesh'),
    (421,'ML','Ganesh')
}

# %%
df4 = pd.DataFrame(my_list)

# %%
df4
# Out:
#      0   1       2
# 0  101  SE    Arun
# 1  421  ML  Ganesh
# 2  150  AI  Mahesh

# %% [markdown]
# # Header

# %%
df5 = pd.DataFrame(my_list,columns=['id','role','name'])

# %%
df5
# Out:
#     id role    name
# 0  101   SE    Arun
# 1  421   ML  Ganesh
# 2  150   AI  Mahesh

# %% [markdown]
# # convert DF into csv

# %%
df5.to_csv('newcsvdf5.csv')

# %%
pwd
# Out:
# 'C:\\Users\\LENOVO\\ML Practice'

# %% [markdown]
# # Converting DF into excel

# %%
df5.to_excel('df5excel.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\LENOVO\\ML Practice'

# %% [markdown]
# # Creating DF into Dictionary

# %%
df5.to_dict()
# Out:
# {'id': {0: 101, 1: 421, 2: 150},
#  'role': {0: 'SE', 1: 'ML', 2: 'AI'},
#  'name': {0: 'Arun', 1: 'Ganesh', 2: 'Mahesh'}}

# %% [markdown]
# # Creating DF by using list of dictionary

# %%
p = [
    {0: 101, 1: 421, 2: 150},
     {0: 'SE', 1: 'ML', 2: 'AI'},
     {0: 'Arun', 1: 'Ganesh', 2: 'Mahesh'}
    ]

# %%
df6 = pd.DataFrame(p)

# %%
df6
# Out:
#       0       1       2
# 0   101     421     150
# 1    SE      ML      AI
# 2  Arun  Ganesh  Mahesh

# %%
Q = [
    {'name':'arun','role':'AI','sal':51000},
    {'name':'mahesh','role':'AI','sal':150000},
    {'name':'sham','role':'SE','sal':10000}
]

# %%
df7 = pd.DataFrame(Q)

# %%
df7
# Out:
#      name role     sal
# 0    arun   AI   51000
# 1  mahesh   AI  150000
# 2    sham   SE   10000

# %% [markdown]
# # Creating DF By Using Web Scrapping

# %%
df8 = pd.read_html('https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_and_territory')

# %%
df8[15]
# Out:
#                           Region[28]  Total cases  Total deaths  \
# 0                     European Union    122910174       1042477
# 1                      North America     82591726       1009657
# 2                       Other Europe     49399121        464715
# 3                      South America     55618428       1260195
# 4            Russia and Central Asia     21527970        408851
# 5                    Central America      8730876        368063
# 6                        Middle East     20373305        230653
# 7                          Caribbean      2319718         24411
# 8   Oceania and islands in East Asia     21352774        251061
# 9                         South Asia     48512568        609503
# 10                      North Africa      3480298         82049
# 11                         East Asia     32161454        155615
# 12                Sub-Saharan Africa      7857245        168553
# 13               Totals (or average)    476835657       6075803
#
# ...

# %%
df8[15].shape   # to know the rows and columns
# Out:
# (14, 9)

# %% [markdown]
# # Creating DF from json  means data comes from API

# %%
df9 = pd.read_json('https://api.sampleapis.com/baseball/hitsSingleSeason')

# %%
df9
# Out:
#    Rank         Player  AgeThatYear   Hits  Year Bats  id
# 0    13  Rishabh Panth           32   2010  2022    L  88
# 1    56       KL Rahul           30  13845  2021    R  89
# 2    54    Virat Kohli           35   2436  2018    R  90
# 3    13  Rishabh Panth           32   2010  2022    L  91
# 4    13  Rishabh Panth           32   2010  2022    L  92

# %%
df10 =pd.read_json('https://api.sampleapis.com/beers/ale')

# %%
df10
# Out:
#       price                                             name  \
# 0     $1.99                        Bell's Double Two Hearted
# 1    $18.49              Founders Underground Mountain Brown
# 2    $10.99                           Bell's Two Hearted Ale
# 3    $89.99  Blue Moon Belgian White Belgian-Style Wheat Ale
# 4    $11.49                           Elysian Space Dust IPA
# ..      ...                                              ...
# 119  $17.99                                       Piraat Ale
# 120   $6.49                             Lindeman's Framboise
# 121  $13.99  Blue Moon Belgian White Belgian-Style Wheat Ale
# 122  $11.99                   Chimay Cinq Cents White Triple
# 123   $2.99                     Bell's Double Two HeartedTWO
#
#                                              rating  \
# 0                                [average, reviews]
# 1    {'average': 2.144647105900939, 'reviews': 319}
# 2    {'average': 2.857913327526303, 'reviews': 440}
# ...

# %% [markdown]
# # converting DF into CSV

# %%
df10.to_csv('Apidata.csv')

# %%
df10.to_json('Api.json')

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.metrics import det_curve

# %%
df1 = pd.read_csv('D:\\python class\\NOTES\\creditcard.csv')

# %%
df1
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df1.shape
# Out:
# (284807, 31)

# %%
df1['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# upscalling

# %%
split dataset
# Out:
#   File "C:\Users\yoges\AppData\Local\Temp/ipykernel_18820/3952680960.py", line 1
#     split dataset
#           ^
# SyntaxError: invalid syntax

# %%
X = df1.drop('Class',axis=1)

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y = df1['Class']

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30)

# %%
X_train.shape
# Out:
# (199364, 30)

# %%
X_test.shape
# Out:
# (85443, 30)

# %%
y_train.shape
# Out:
# (199364,)

# %%
y_test.shape
# Out:
# (85443,)

# %%
pip install imblearn

# %%
pip install --upgrade -m pip
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   C:\Users\yoges\anaconda3\python.exe -m pip install [options] <requirement specifier> [package-index-options] ...
#   C:\Users\yoges\anaconda3\python.exe -m pip install [options] -r <requirements file> [package-index-options] ...
#   C:\Users\yoges\anaconda3\python.exe -m pip install [options] [-e] <vcs project url> ...
#   C:\Users\yoges\anaconda3\python.exe -m pip install [options] [-e] <local project path> ...
#   C:\Users\yoges\anaconda3\python.exe -m pip install [options] <archive url/path> ...
#
# no such option: -m

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
os = RandomOverSampler(0.75)
# Out:
# C:\Users\yoges\anaconda3\lib\site-packages\imblearn\utils\_validation.py:586: FutureWarning: Pass sampling_strategy=0.75 as keyword args. From version 0.9 passing these as positional arguments will result in an error
#   warnings.warn(

# %%
X_train_ns,y_train_ns = os.fit_resample(X_train,y_train)

# %%
X_train_ns.value_counts()
# Out:
# Time      V1          V2          V3          V4         V5          V6         V7          V8          V9         V10         V11        V12         V13        V14         V15        V16         V17         V18        V19        V20        V21         V22        V23        V24        V25        V26        V27        V28        Amount
# 68207.0   -13.192671   12.785971  -9.906650    3.320337  -4.801176    5.760059  -18.750889  -37.353443  -0.391540  -5.052502    4.406806  -4.610756   -1.909488  -9.072711   -0.226074  -6.211557   -6.248145   -3.149247   0.051576  -3.493050   27.202839  -8.887017   5.303607  -0.639435   0.263203  -0.108877   1.269566   0.939407  1.00      1233
# ...

# %%
y_train_ns.value_counts()
# Out:
# 0    199015
# 1    149261
# Name: Class, dtype: int64

# %%
import pandas as pd

# %%
df1
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df2 = pd.read_csv('D:\\python class\\NOTES\\creditcard.csv')

# %%
df2
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df2.shape
# Out:
# (284807, 31)

# %%
df2['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df2.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
len(df2.columns)
# Out:
# 31

# %%
df3 = df2.iloc[:,0:30]

# %%
df3
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
df4 = df3[[col for col in df3.columns if col !='Class' ]]

# %%
df4
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
X = df4

# %%
y = df2['Class']

# %%
y.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
obj = RandomOverSampler(0.80)
# Out:
# C:\Users\yoges\anaconda3\lib\site-packages\imblearn\utils\_validation.py:586: FutureWarning: Pass sampling_strategy=0.8 as keyword args. From version 0.9 passing these as positional arguments will result in an error
#   warnings.warn(

# %%
X_new,y_new = obj.fit_resample(X,y)

# %%
X_new.shape
# Out:
# (511767, 30)

# %%
y_new.shape
# Out:
# (511767,)

# %%
from imblearn.under_sampling import NearMiss

# %%
obj2 = NearMiss(0.80)
# Out:
# C:\Users\yoges\anaconda3\lib\site-packages\imblearn\utils\_validation.py:586: FutureWarning: Pass sampling_strategy=0.8 as keyword args. From version 0.9 passing these as positional arguments will result in an error
#   warnings.warn(

# %%
X_down,y_down = obj2.fit_resample(X,y)

# %%
X_down.shape
# Out:
# (1107, 30)

# %%
y_down.shape
# Out:
# (1107,)

# %%
X_down.value_counts()
# Out:
# Time      V1          V2          V3          V4         V5          V6         V7          V8          V9         V10         V11        V12         V13        V14         V15        V16         V17         V18        V19        V20        V21         V22        V23        V24        V25        V26        V27        V28        Amount
# 68207.0   -13.192671   12.785971  -9.906650    3.320337  -4.801176    5.760059  -18.750889  -37.353443  -0.391540  -5.052502    4.406806  -4.610756   -1.909488  -9.072711   -0.226074  -6.211557   -6.248145   -3.149247   0.051576  -3.493050   27.202839  -8.887017   5.303607  -0.639435   0.263203  -0.108877   1.269566   0.939407  1.00      6
# ...

# %%
y_down.value_counts()
# Out:
# 0    615
# 1    492
# Name: Class, dtype: int64

# %%
import pandas as pd

# %%
df6 = pd.read_csv('D:\\python class\\NOTES\\Bengaluru_House_Data.csv')

# %%
df6
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df6.shape
# Out:
# (13320, 9)

# %%
df6.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
drop = df6.drop('society',axis=1)

# %%
drop
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size total_sqft  bath  balcony   price
# 0          2 BHK       1056   2.0      1.0   39.07
# ...

# %%
drop.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          1
# size             16
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
fillna = drop.fillna(0)

# %%
fillna
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size total_sqft  bath  balcony   price
# 0          2 BHK       1056   2.0      1.0   39.07
# ...

# %%
fillna.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
fillna['balcony'].unique
# Out:
# <bound method Series.unique of 0        1.0
# 1        3.0
# 2        3.0
# 3        1.0
# 4        1.0
#         ...
# 13315    0.0
# 13316    0.0
# 13317    1.0
# 13318    1.0
# 13319    1.0
# Name: balcony, Length: 13320, dtype: float64>

# %%
import seaborn as sns

# %%
sns.boxplot(data=fillna)
# Out:
# <AxesSubplot:>

# %%
df6
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df6['balcony']
# Out:
# 0        1.0
# 1        3.0
# 2        3.0
# 3        1.0
# 4        1.0
#         ...
# 13315    0.0
# 13316    NaN
# 13317    1.0
# 13318    1.0
# 13319    1.0
# Name: balcony, Length: 13320, dtype: float64

# %%
df6['balcony'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        1.0
# 1        3.0
# 2        3.0
# 3        1.0
# 4        1.0
#         ...
# 13315    0.0
# 13316    NaN
# 13317    1.0
# 13318    1.0
# 13319    1.0
# Name: balcony, Length: 13320, dtype: float64>

# %%
df6['balcony'].isnull().sum()
# Out:
# 609

# %%
df6['balcony']=df6['balcony'].fillna(df6['balcony'].mean())

# %%
df6['balcony']
# Out:
# 0        1.000000
# 1        3.000000
# 2        3.000000
# 3        1.000000
# 4        1.000000
#            ...
# 13315    0.000000
# 13316    1.584376
# 13317    1.000000
# 13318    1.000000
# 13319    1.000000
# Name: balcony, Length: 13320, dtype: float64

# %%
df6['balcony'].isnull().sum()
# Out:
# 0

# %%
df6['bath']
# Out:
# 0        2.0
# 1        5.0
# 2        2.0
# 3        3.0
# 4        2.0
#         ...
# 13315    4.0
# 13316    5.0
# 13317    2.0
# 13318    4.0
# 13319    1.0
# Name: bath, Length: 13320, dtype: float64

# %%
df6['bath'].isnull().sum()
# Out:
# 73

# %%
df6['bath'].median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0        2.0
# 1        5.0
# 2        2.0
# 3        3.0
# 4        2.0
#         ...
# 13315    4.0
# 13316    5.0
# 13317    2.0
# 13318    4.0
# 13319    1.0
# Name: bath, Length: 13320, dtype: float64>

# %%
df6
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath   balcony   price
# 0          2 BHK  Coomee        1056   2.0  1.000000   39.07
# ...

# %%
df6.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df6['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
for i in df6['total_sqft'].unique():
    print(i)
# Out:
# 1056
# 2600
# 1440
# 1521
# 1200
# 1170
# 2732
# 3300
# 1310
# 1020
# 1800
# 2785
# 1000
# 1100
# 2250
# 1175
# 1180
# 1540
# 2770
# 600
# 1755
# 2800
# 1767
# 510
# 1250
# 660
# 1610
# 1151
# 1025
# 2100 - 2850
# 1075
# 1760
# 1693
# 1925
# 700
# 1070
# 1724
# 1290
# 1143
# 1296
# 1254
# 1330.74
# 970
# 1459
# 800
# 869
# 1270
# 1670
# 2010
# 1185
# 1600
# 3010 - 3410
# 1500
# 1407
# 840
# 4395
# 845
# 5700
# 1160
# 3000
# 1140
# 1220
# 1350
# 1005
# 500
# 1358
# 1569
# 1240
# 2089
# 1206
# 1150
# 2511
# 460
# 4400
# 1660
# 2957 - 3450
# 1326
# 1325
# 1499
# 1665
# 708
# 1060
# 710
# 1450
# 2894
# 1330
# 2502
# 650
# 2400
# 1007
# 966
# 1630
# 1640
# 782
# 1260
# 1413
# 1116
# 1530
# 3700
# 2497
# 1436
# 276
# 1427
# 2061
# 3067 - 8156
# 2650
# 1282
# 1050
# 945
# 950
# 1870
# 880
# 1535
# 1360
# 1042 - 1105
# 1280
# 5000
# 3050
# 1563.05
# 1167
# 4000
# 1828
# 890
# 1612
# 1034
# 1710
# 957
# 2795
# 1125
# 1735
# 2050
# 3750
# 1063
# 1904
# 4200
# 2000
# 1145 - 1340
# 1425
# 1470
# ...

# %%
import re

# %%
def test(x):
    obj3 = re.findall(r'\d+',x)
    if len(obj3)>1:
        return (int(obj3[0])+int(obj3[1]))/2
    return obj3 [0]

# %%
df6['total_sqft_new']=df6['total_sqft'].apply(test)

# %%
df6['total_sqft_new']
# Out:
# 0        1056
# 1        2600
# 2        1440
# 3        1521
# 4        1200
#          ...
# 13315    3453
# 13316    3600
# 13317    1141
# 13318    4689
# 13319     550
# Name: total_sqft_new, Length: 13320, dtype: object

# %%
df6
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath   balcony   price total_sqft_new
# ...

# %%
df6['total_sqft_new']=df6['total_sqft_new'].astype('int')

# %%
df6['total_sqft_new']
# Out:
# 0        1056
# 1        2600
# 2        1440
# 3        1521
# 4        1200
#          ...
# 13315    3453
# 13316    3600
# 13317    1141
# 13318    4689
# 13319     550
# Name: total_sqft_new, Length: 13320, dtype: int32

# %%
df6['total_sqft_new'].value_counts()
# Out:
# 1200    843
# 1100    223
# 1500    208
# 2400    196
# 600     180
#        ...
# 2155      1
# 555       1
# 4830      1
# 2383      1
# 4689      1
# Name: total_sqft_new, Length: 1928, dtype: int64

# %%
df6['total_sqft_new'].unique
# Out:
# <bound method Series.unique of 0        1056
# 1        2600
# 2        1440
# 3        1521
# 4        1200
#          ...
# 13315    3453
# 13316    3600
# 13317    1141
# 13318    4689
# 13319     550
# Name: total_sqft_new, Length: 13320, dtype: int32>

# %%
sns.scatterplot(df6['bath'],df6['total_sqft_new'])
# Out:
# C:\Users\yoges\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bath', ylabel='total_sqft_new'>
